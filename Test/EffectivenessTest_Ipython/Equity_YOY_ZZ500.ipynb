# %%
import EffectivenessTest as ET

#因子，指数，年份（单独看某一年的话，year=某一年，全部回测时间的话，year=0）,分组数
ET.Effectiveness_Test('Equity_YOY','ZZ500',0,10)
# Out:
# Equity_YOY ZZ500
# Dropped 20.9% entries from factor data (20.9% after in forward returns computation and 0.0% in binning phase). Set max_loss=0 to see potentially suppressed Exceptions.
# Quantiles Statistics
#                       min          max      mean        std  count    count %
# factor_quantile
# 1               -0.666136     0.011312 -0.100459   0.096105  99318  10.115168
# 2               -0.102718     0.035456 -0.008185   0.019062  98047   9.985721
# 3               -0.036448     0.057077  0.014391   0.013570  97808   9.961380
# 4               -0.010977     0.077158  0.030719   0.013771  98093   9.990406
# 5                0.007390     0.099389  0.047000   0.015890  98307  10.012201
# 6                0.022866     0.126517  0.065289   0.018811  97523   9.932354
# 7                0.033756     0.172210  0.089489   0.024458  97847   9.965352
# 8                0.053145     0.349274  0.127157   0.036481  98054   9.986434
# 9                0.076654     0.859669  0.226925   0.103743  97801   9.960667
# 10               0.115342  2494.474680  3.570873  76.555564  99074  10.090317
# Returns Analysis
#                                                   5      10     20     30  \
# Ann. alpha                                     0.006  0.004  0.004  0.002
# beta                                          -0.029 -0.035 -0.039 -0.042
# Mean Period Wise Return Top Quantile (bps)    -0.163 -0.308 -0.322 -0.358
# Mean Period Wise Return Bottom Quantile (bps)  0.214  0.341  0.504  0.359
# Mean Period Wise Spread (bps)                 -0.338 -0.598 -0.764 -0.620
#
#                                                   60     90
# Ann. alpha                                    -0.001 -0.002
# beta                                          -0.041 -0.011
# Mean Period Wise Return Top Quantile (bps)    -0.471 -0.414
# Mean Period Wise Return Bottom Quantile (bps)  0.356  0.360
# Mean Period Wise Spread (bps)                 -0.742 -0.678
# Information Analysis
#                      5      10     20     30     60     90
# IC Mean           0.008  0.008  0.008  0.008  0.005  0.002
# IC Std.           0.091  0.100  0.108  0.110  0.105  0.096
# Risk-Adjusted IC  0.087  0.081  0.073  0.071  0.051  0.024
# t-stat(IC)        4.394  4.096  3.690  3.567  2.563  1.221
# p-value(IC)       0.000  0.000  0.000  0.000  0.010  0.222
# IC Skew           0.315  0.405  0.342  0.317  0.348  0.280
# IC Kurtosis       1.280  1.651  1.448  1.356  0.897  0.755
# Turnover Analysis
#                                 5     10     20     30     60     90
# Quantile 1 Mean Turnover    0.117  0.152  0.238  0.296  0.487  0.637
# Quantile 2 Mean Turnover    0.158  0.207  0.316  0.393  0.605  0.740
# Quantile 3 Mean Turnover    0.177  0.237  0.359  0.445  0.665  0.790
# Quantile 4 Mean Turnover    0.192  0.256  0.384  0.470  0.683  0.810
# Quantile 5 Mean Turnover    0.201  0.267  0.398  0.487  0.696  0.821
# Quantile 6 Mean Turnover    0.203  0.271  0.404  0.497  0.707  0.829
# Quantile 7 Mean Turnover    0.197  0.262  0.392  0.483  0.686  0.807
# Quantile 8 Mean Turnover    0.186  0.247  0.374  0.458  0.655  0.776
# Quantile 9 Mean Turnover    0.166  0.216  0.326  0.396  0.580  0.708
# Quantile 10 Mean Turnover   0.128  0.166  0.258  0.319  0.508  0.652
#                                       5    10   20     30     60     90
# Mean Factor Rank Autocorrelation  0.975  0.95  0.9  0.851  0.708  0.574
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# 564.95416256
