# %%
import EffectivenessTest as ET

#因子，指数，年份（单独看某一年的话，year=某一年，全部回测时间的话，year=0）,分组数
ET.Effectiveness_Test('PB_MRQ_OPP','ZZ500',0,10)
# Out:
# PB_MRQ_OPP ZZ500
# Dropped 20.9% entries from factor data (20.9% after in forward returns computation and 0.0% in binning phase). Set max_loss=0 to see potentially suppressed Exceptions.
# Quantiles Statistics
#                        min       max      mean       std  count    count %
# factor_quantile
# 1               -64.910993 -2.452605 -8.836724  4.180548  99870  10.113756
# 2               -12.770023 -1.858561 -5.397583  1.488991  98598   9.984941
# 3                -9.460113 -1.517839 -4.318020  1.159628  98401   9.964991
# 4                -7.292361 -1.326305 -3.653508  0.970397  98627   9.987878
# 5                -6.308525 -1.200423 -3.176737  0.838838  98862  10.011676
# 6                -5.378106 -1.064443 -2.777395  0.733774  98095   9.934003
# 7                -4.702254 -0.974399 -2.413541  0.651540  98382   9.963067
# 8                -4.110443 -0.856247 -2.071830  0.584324  98646   9.989802
# 9                -3.519787 -0.729926 -1.708729  0.509673  98353   9.960130
# ...
