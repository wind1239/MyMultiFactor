# %%
import EffectivenessTest as ET

Factor='CFPS_LYR'
Index='ZZ500'
Year=0 #单独看某一年的话，year=某一年，全部回测时间的话，year=0
Quantile=10

ET.Effectiveness_Test(Factor,Index,Year,Quantile)
# Out:
# CFPS_LYR ZZ500
# Dropped 20.9% entries from factor data (20.9% after in forward returns computation and 0.0% in binning phase). Set max_loss=0 to see potentially suppressed Exceptions.
# Quantiles Statistics
#                       min        max      mean       std  count    count %
# factor_quantile
# 1               -6.042350  -0.241347 -0.998924  0.684608  99310  10.115074
# 2               -0.944695  -0.090148 -0.378373  0.164020  98042   9.985924
# 3               -0.578088   0.006048 -0.180547  0.097720  97803   9.961581
# 4               -0.302647   0.066850 -0.068025  0.065699  98078   9.989591
# 5               -0.138180   0.153976  0.009610  0.053694  98308  10.013017
# 6               -0.052612   0.281311  0.089576  0.064310  97516   9.932349
# 7                0.023794   0.432393  0.191309  0.079970  97833   9.964636
# 8                0.094675   0.776092  0.346943  0.115643  98048   9.986535
# 9                0.208006   1.507436  0.636027  0.222412  97797   9.960970
# 10               0.401377  30.467758  1.836188  1.653617  99067  10.090324
# Returns Analysis
#                                                   5      10     20     30  \
# Ann. alpha                                     0.010  0.008  0.005  0.004
# beta                                          -0.007 -0.006 -0.007 -0.005
# Mean Period Wise Return Top Quantile (bps)    -0.783 -0.661 -0.449 -0.496
# Mean Period Wise Return Bottom Quantile (bps) -0.043 -0.121 -0.063  0.065
# Mean Period Wise Spread (bps)                 -0.605 -0.443 -0.336 -0.551
#
#                                                   60     90
# Ann. alpha                                     0.002  0.001
# beta                                          -0.004 -0.014
# Mean Period Wise Return Top Quantile (bps)    -0.305  0.069
# Mean Period Wise Return Bottom Quantile (bps) -0.223 -0.200
# Mean Period Wise Spread (bps)                 -0.139  0.198
# Information Analysis
#                      5      10     20     30     60     90
# IC Mean           0.001  0.001  0.002  0.001  0.001  0.004
# IC Std.           0.059  0.058  0.057  0.059  0.060  0.056
# Risk-Adjusted IC  0.015  0.024  0.035  0.021  0.014  0.062
# t-stat(IC)        0.762  1.208  1.787  1.046  0.718  3.135
# p-value(IC)       0.446  0.227  0.074  0.296  0.473  0.002
# IC Skew           0.117 -0.006 -0.073  0.148  0.360  0.358
# IC Kurtosis       0.118  0.007 -0.089 -0.026 -0.039  0.107
